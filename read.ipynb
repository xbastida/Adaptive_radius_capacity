# %%
import geopandas as gpd
from pathlib import Path

# %%
current_dir = Path.cwd()
escritorio = current_dir.parent.parent.parent
print(escritorio)
# Out:
# /home/xabi9

# %%
primero = gpd.read_file(escritorio / "adaptive.gpkg")
print(primero.shape)
print(primero.columns)
# Out:
# (70, 20)
# Index(['ID', 'Nombre', 'Grupo', 'Total de anclajes', 'Latitud', 'Longitud',
#        'Estación inicial/expansión', 'Primera aparición Salida',
#        'Primera aparición Llegada', 'Acometida Eléctrica', 'Geltoki +',
#        'Elevación', 'h3_res_11', 'h3_res_10', 'h3_res_9', 'Acometida_binario',
#        'adaptive_radius_m', 'covered_filling', 'saturated', 'geometry'],
#       dtype='str')

# %%
segundo = gpd.read_file(escritorio / "yessir.gpkg")
print(segundo.shape)
print(segundo.columns)
# Out:
# (70, 20)
# Index(['ID', 'Nombre', 'Grupo', 'Total de anclajes', 'Latitud', 'Longitud',
#        'Estación inicial/expansión', 'Primera aparición Salida',
#        'Primera aparición Llegada', 'Acometida Eléctrica', 'Geltoki +',
#        'Elevación', 'h3_res_11', 'h3_res_10', 'h3_res_9', 'Acometida_binario',
#        'adaptive_radius_m', 'covered_filling', 'saturated', 'geometry'],
#       dtype='str')

# %%
media1 = primero["adaptive_radius_m"].mean()
media2 = segundo["adaptive_radius_m"].mean()
print(f"Media 1: ", media1, "Media2: ", media2)
# Out:
# Media 1:  410.85714285714283 Media2:  399.72670248002146
